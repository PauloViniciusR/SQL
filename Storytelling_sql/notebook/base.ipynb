# %% [markdown]
# # Criando uma história com os dados
# - Vamos utilizar a base disponível em:
#     - https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce?select=olist_customers_dataset.csv
#     - Todos os arquivos estão disponíveis para download no link abaixo:
#         - https://drive.google.com/drive/folders/1yzu_8qvCXOzHTVTyVRTk5gdd_ki93Em4?usp=sharing

# %% [markdown]
# **Relembrando**
# - https://docs.python.org/3/library/os.html

# %%
# Importando a biblioteca
import os

# %%
# Guardando a pasta atual em uma variável
pasta_atual = os.getcwd()
pasta_bases = os.path.join("..", "bases")

arquivos = os.listdir(pasta_bases)

# %%
# Visualizando os arquivos
arquivos
# Out:
# ['olist_order_payments_dataset.csv',
#  'olist_orders_dataset.csv',
#  'olist_customers_dataset.csv',
#  'olist_geolocation_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_sellers_dataset.csv',
#  'product_category_name_translation.csv',
#  'olist_products_dataset.csv',
#  'olist_order_reviews_dataset.csv']

# %%
# Importando o pandas

# %%
# Visualizando a olist_orders_dataset

# %%
# Visualizando as 5 primeiras linhas

# %% [markdown]
# **Criando nosso banco de dados**
# - https://docs.python.org/3/library/sqlite3.html

# %%
# Importando o sqlite3

# %%
# Criando a conexão e o nosso DB

# %%
# Percorrendo toda a lista de arquivos

# %%
# Criando o cursor

# %%
# Selecionando os 2 primeiros registros de qualquer tabela

# %% [markdown]
# **Visualizando novamente a tabela de ordens**

# %%
# Visualizando as 2 primeiras linhas

# %%
# Verificando as informações da base

# %%
# Fazendo o tratamento para as colunas de datas
datas = ['order_purchase_timestamp','order_approved_at','order_delivered_carrier_date',
         'order_delivered_customer_date','order_estimated_delivery_date']

# %%
# Substituindo a base antiga por essa no sql

# %%
# Selecionando os registros dessa tabela

# %% [markdown]
# **Criando a função para transformar nossa consulta em um DataFrame do pandas**

# %%
# Fazendo qualquer consulta nessa tabela e guardando na variável resultado

# %%
# Visualizando esse resultado

# %%
# Transformando em um DataFrame

# %%
# Visualizando o DataFrame

# %%
# Utilizando o description para visualizar o nome das colunas

# %%
# Atribuindo essas colunas ao dataframe

# %% [markdown]
# **Também é importante fazermos o tratamento para o caso do resultado não ter nenhuma coluna**

# %%
# Verificando o shape do resultado

# %%
# Utilizando apenas a quantidade de colunas

# %%
# Printando o resultado

# %%
# Agora podemos transformar tudo isso em uma função do Python
